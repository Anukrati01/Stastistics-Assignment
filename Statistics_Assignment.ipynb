# %% [markdown]
# # **Statistics**

# %% [markdown]
# 1. Explain the different types of data (qualitative and quantitative) and provide examples of each. Discuss
# nominal, ordinal, interval, and ratio scales.
#
#     -**Qualitative**:
#
#      Descriptive information that cannot be easily measured numerically, often focusing on opinions, perceptions, or experiences.
#
#      Examples:
#     - Customer feedback on a new product ("good", "average", "poor").
#     - Interview transcripts about someone's feelings on a topic.
#     - Observations of patient behavior in a clinical setting.
#     - Open-ended survey responses about favorite hobbies.
#
#    **Quantitative**
#
#   Numerical data that can be counted or measured, allowing for statistical analysis.
#
#   Examples:
#    - A person's height in centimeters
#    - Temperature in degrees Celsius
#    - Number of cars on a highway
#    - Income level in dollars

# %% [markdown]
# 2. What are the measures of central tendency, and when should you use each? Discuss the mean, median,
# and mode with examples and situations where each is appropriate.
#      - **Measures of Central Tendency Meaning**
#
#           The representative value of a data set, generally the central value or the most occurring value that gives a general idea of the whole data set is called Measure of Central Tendency.
#
#           **Some of the most commonly used measures of central tendency are:**
#              - Mean
#             - Median
#               - Mode
#     **Mean:-**
# Arithmetic mean is defined as the sum of the individual observations (xi) divided by the total number of observations N. In other words, the mean is given by the sum of all observations divided by the total number of observations. short form of mean(Average: Arithmatic mid value of data.)
#
#          x
# ˉ
#  =
# ∑x
# i/N
# ​
#
#           OR
#
#      Mean = Sum of all Observations ÷ Total number of Observations
#
#
#
# **Example:** If there are 5 observations, which are 27, 11, 17, 19, and 21 then the mean  is given by
#
#
#
#   X  = (27 + 11 + 17 + 19 + 21) ÷ 5
#
# ⇒ X
#  = 95 ÷ 5
#
# ⇒ X = 19
#
#   **Median:-**(physical mid ponit of data) , the observations must be arranged in ascending or descending order. If the total number of observations is N then there are two cases
#
# Case 1: N is Odd
#
# Median = Value of observation at [(n + 1) ÷ 2]th Position
#
#    Case 2: N is Even
#
# Median = Arithmetic mean of Values of observations at (n ÷ 2)th and [(n ÷ 2) + 1]th Position
#
#    Example 1: If the observations are 25, 36, 31, 23, 22, 26, 38, 28, 20, 32 then the Median is given by
#
# Arranging the data in ascending order: 20, 22, 23, 25, 26, 28, 31, 32, 36, 38
#
#
# N = 10 which is even then
#
#
# Median = Arithmetic mean of values at (10 ÷ 2)th and [(10 ÷ 2) + 1]th position
#
#
# ⇒ Median = (Value at 5th position + Value at 6th position) ÷ 2
#
#
# ⇒ Median = (26 + 28) ÷ 2
#
#
# ⇒ Median = 27
#
# Example 2: If the observations are 25, 36, 31, 23, 22, 26, 38, 28, 20 then the Median is given by
#
# Arranging the data in ascending order: 20, 22, 23, 25, 26, 28, 31, 36, 38
#
#
# N = 9 which is odd then
#
#
# Median = Value at [(9 + 1) ÷ 2]th position
#
#
# ⇒ Median = Value at 5th position
#
#
# ⇒ Median = 26
#
# **Mode:-** Mode is the value of that observation which has a maximum frequency corresponding to it. In other, that observation of the data occurs the maximum number of times in a dataset.
#
# Example: Find the mode of observations 5, 3, 4, 3, 7, 3, 5, 4, 3.
#
#           Highest frequency of gven data is 3.
#            hence, mode=3

# %% [markdown]
# 3. Explain the concept of dispersion. How do variance and standard deviation measure the spread of data?
#     - Measures of Dispersion measure the scattering of the data. It tells us how the values are distributed in the data set. In statistics, we define the measure of dispersion as various parameters that are used to define the various attributes of the data.
#
#      **Variance**
#
#       The variance of the data is given by measuring the distance of the observed values from the mean of the distribution. Here we are not concerned with the sign of the distance of the point, we are more interested in the magnitude. So, we take squares of the distance from the mean. Let’s say we have x1, x2, x3 …. xn as n observations and x
# ˉ
#  be the mean.
#
#     (x
# 1
# ​
#  –
# x
# ˉ
#  )
# 2
#  +(x
# 2
# ​
#  –
# x
# ˉ
#  )
# 2
#  +(x
# 3
# ​
#  –
# x
# ˉ
#  )
# 2
#  ….(x
# n
# ​
#  –
# x
# ˉ
#  )
# 2
#  =∑
# 0
# n
# ​
#  (x
# i
# ​
#  –
# x
# ˉ
#  )
# 2
#
#
#
#
#
#    Variance =
# n
# ∑
# 0
# n
# ​
#  (x
# i
# ​
#  –
# x
# ˉ
#  )
# 2
#
# ​
#
# σ
# 2
#  =
# n
# ∑
# 0
# n
# ​
#  (x
# i
# ​
#  –
# x
# ˉ
#  )
# 2
#
# ​
#
#  ** standard deviation **
#
#   In the calculation of variance, notice that the units of the variance and the unit of the observations are not the same. So, to remove this problem, we define standard deviation. It is denoted as:

# %% [markdown]
# 4. What is a box plot, and what can it tell you about the distribution of data?
#     - Box Plot is a graphical method to visualize data distribution for gaining insights and making informed decisions. Box plot is a type of chart that depicts a group of numerical data through their quartiles.
#
#       A box plot gives a five-number summary of a set of data which is-
#
#       1. Minimum –  It is the minimum value in the dataset excluding the outliers.
#       2. First Quartile (Q1) – 25% of the data lies below the First (lower) Quartile.
#       3. Median (Q2) – It is the mid-point of the dataset. Half of the values lie below it and half above.
#       4. Third Quartile (Q3) – 75% of the data lies below the Third (Upper) Quartile.
#       5. Maximum – It is the maximum value in the dataset excluding the outliers.

# %% [markdown]
# 5. Discuss the role of random sampling in making inferences about populations.
#     - Random sampling plays a crucial role in making inferences about populations by ensuring that a selected sample is representative of the larger population, allowing researchers to draw conclusions about the population characteristics based on the data collected from that sample, minimizing bias and increasing the validity of the inferences made.

# %% [markdown]
# 6. Explain the concept of skewness and its types. How does skewness affect the interpretation of data?
#      - Skewness is a measure of asymmetry or distortion of symmetric distribution. It measures the deviation of the given distribution of a random variable from a symmetric distribution, such as normal distribution. A normal distribution is without any skewness, as it is symmetrical on both sides. Hence, a curve is regarded as skewed if it is shifted towards the right or the left.
#
#        **Types of skewness**
#       1. Positive Skewness:-
#          If the given distribution is shifted to the left and with its tail on the right side, it is a positively skewed distribution. It is also called the right-skewed distribution. A tail is referred to as the tapering of the curve differently from the data points on the other side.
#
#             As the name suggests, a positively skewed distribution assumes a skewness value of more than zero. Since the skewness of the given distribution is on the right, the mean value is greater than the median and moves towards the right, and the mode occurs at the highest frequency of the distribution.
#
#       2. Negative Skewness:-
#
#          If the given distribution is shifted to the right and with its tail on the left side, it is a negatively skewed distribution. It is also called a left-skewed distribution. The skewness value of any distribution showing a negative skew is always less than zero. The skewness of the given distribution is on the left; hence, the mean value is less than the median and moves towards the left, and the mode occurs at the highest frequency of the distribution.
#
#   skewness significantly affects the interpretation of data by indicating the asymmetry of a distribution, meaning if the data is clustered more towards one side of the scale, which can lead to misleading conclusions if not properly considered when analyzing the mean, median, and overall trend of the data, particularly when outliers are present; a positively skewed distribution has a longer tail on the right side, while a negatively skewed one has a longer tail on the left side.

# %% [markdown]
# 7. What is the interquartile range (IQR), and how is it used to detect outliers?
#   - Outlier Detection and Removal using the IQR Method | by ...The interquartile range (IQR) is a statistical measure that represents the spread of the middle 50% of a data set, calculated by subtracting the first quartile (Q1) from the third quartile (Q3); it is commonly used to identify outliers by setting "fences" beyond which data points are considered outliers, typically by multiplying the IQR by 1.5 and adding/subtracting that value from Q3 and Q1 respectively.
#
#
#
#   The Interquartile Range (IQR) is used to detect outliers by calculating a "fence" around the middle 50% of your data, where any data points falling significantly outside this range are considered outliers; typically, this is done by adding and subtracting 1.5 times the IQR from the first and third quartiles respectively, with values outside this range being identified as outliers.

# %% [markdown]
# 8. Discuss the conditions under which the binomial distribution is used.
#       - Binomial Distribution is a probability distribution used to model the number of successes in a fixed number of independent trials, where each trial has only two possible outcomes: success or failure. This distribution is useful for calculating the probability of a specific number of successes in scenarios like flipping coins, quality control, or survey predictions.
#
#          **Conditions for Binomial Distribution**
# The Binomial distribution can be used in scenarios where the following conditions are satisfied:
#
#        1. Fixed Number of Trials: There are a set number of trials or experiments (denoted by n), such as flipping a coin 10 times.
#        2. Two Possible Outcomes: Each trial has only two possible outcomes, often labeled as “success” and “failure.” For example, getting heads or tails in a coin flip.
#        3. Independent Trials: The outcome of each trial is independent of the others, meaning the result of one trial does not affect the result of another.
#        4. Constant Probability: The probability of success (denoted by p) remains the same for each trial. For example, if you’re flipping a fair coin, the probability of getting heads is always 0.5.
#
#      The Binomial distribution is an appropriate model to use for calculating the probabilities of obtaining a certain number of successes in the given trials.

# %% [markdown]
# 9. Explain the properties of the normal distribution and the empirical rule (68-95-99.7 rule).
#     - The normal distribution, often visualized as a bell-shaped curve, is a symmetrical probability distribution where most data points cluster around the mean, with progressively fewer values falling further away from the mean; the "empirical rule" (or "68-95-99.7 rule") states that in a normal distribution, roughly 68% of data falls within one standard deviation of the mean, 95% falls within two standard deviations, and 99.7% falls within three standard deviations of the mean.

# %% [markdown]
# 10. Provide a real-life example of a Poisson process and calculate the probability for a specific event.
#    - The Poisson distribution is a probability distribution that is used to model the probability that a certain number of events occur during a fixed time interval when the events are known to occur independently and with a constant mean rate.
#
#         **Example 1: Calls per Hour at a Call Center**
#
#         Call centers use the Poisson distribution to model the number of expected calls per hour that they’ll receive so they know how many call center reps to keep on staff.
#
#         For example, suppose a given call center receives 10 calls per hour. We can use a Poisson distribution calculator to find the probability that a call center receives 0, 1, 2, 3 … calls in a given hour
#
#          P(X = 0 calls) = 0.00005
#
#          P(X = 1 call) = 0.00045
#
#        P(X = 2 calls) = 0.00227
#
#        P(X = 3 calls) = 0.00757
#         And so on.
#
#         This gives call center managers an idea of how many calls they’re likely to receive per hour and enables them to manage employee schedules based on the number of expected calls.

# %% [markdown]
# 11. Explain what a random variable is and differentiate between discrete and continuous random variables.
#    - **A random** variable is a variable whose value is unknown or a function that assigns values to each of an experiment's outcomes. A random variable can be either discrete (having specific values) or continuous (any value in a continuous range).
#
#      **Differentiate between discrete and continuous random variable**
#
#        **1.Discrete Variable:-**
#
#          a)They can take only specific or discrete values.
#
#          b)Discrete variables are typically measured on a nominal or ordinal scale.
#
#         c) Discrete variables are often represented by bar graphs or histograms.
#
#         d) Examples include the number of students in a class or the outcomes of rolling a die.
#
#         e) Discrete variables have probability mass functions (PMF)
#
#         f) They are employed in various mathematical contexts and applications where quantities are counted.
#
#         **2.Continuous Variable:-**
#         a)They can take any value within a specific range.
#
#         b)Continuous variables are typically measured on an interval or ratio scale.
#
#         c)Continuous variables are often represented by line graphs or smooth curves.
#
#         d)Examples include measurements such as length, time, or temperature.
#
#         e)Continuous variables have probability density functions (PDF).
#
#         f)They are often employed in various branches of mathematics, including calculus, differential equations, and real analysis, as well as in applied fields such as physics, engineering and statistics.

# %% [markdown]
# 12. Provide an example dataset, calculate both covariance and correlation, and interpret the results.
#    -  Let's take an example dataset where we want to analyze the relationship between "hours studied" and "exam score" for a group of students:
#
# | Student | Hours Studied (X) | Exam Score (Y) |
# |---|---|---|
# | 1 | 2 | 65 |
# | 2 | 5 | 80 |
# | 3 | 3 | 70 |
# | 4 | 1 | 55 |
# | 5 | 4 | 85 |
# Calculating Covariance:
# Step 1: Find the mean of each variable:
# Mean of "Hours Studied" (X) = (2 + 5 + 3 + 1 + 4) / 5 = 3
# Mean of "Exam Score" (Y) = (65 + 80 + 70 + 55 + 85) / 5 = 71
# Step 2: Calculate the deviations from the mean for each data point:
# For X: [-1, 2, 0, -2, 1]
# For Y: [-6, 9, -1, -16, 14]
# Step 3: Multiply the corresponding deviations and calculate the average:
# Covariance = [( -1) * (-6) + (2) * (9) + (0) * (-1) + (-2) * (-16) + (1) * (14)] / 5 = 38
# Calculating Correlation:
# Step 1: Calculate the standard deviation of each variable:
# Standard deviation of X = 1.58
# Standard deviation of Y = 12.96
# Step 2: Divide the covariance by the product of standard deviations:
# Correlation = (38) / (1.58 * 12.96) = 1.88 (approximately)
